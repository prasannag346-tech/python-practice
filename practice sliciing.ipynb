# %%
# create an list of elements containing 1 to 5
a=[1,2,3,4,5]
print(a[3:-1])
# Out:
# [4]

# %%
a=[1,2,3,4,5,6,7,8,9]
print(a[5:-4])
# Out:
# []

# %%
a=[7,8,5,3,5,8,22]
print(a[3:7])
# Out:
# [3, 5, 8, 22]
