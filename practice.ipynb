# %% [markdown]
# ### Swap

# %%
a = 10
b = 20
print(a,b)
# Out:
# 10 20

# %%
a, b = 10,20
print(a,b)
# Out:
# 10 20

# %%
# Out:
#   Cell In[5], line 3
#     print(a,b = b,a)
#                    ^
# SyntaxError: positional argument follows keyword argument

# %%
a, b = 10,20
a , b = b, a
print(a,b)
# Out:
# 20 10

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool('hi')
# Out:
# True

# %%
bool(hi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 bool(hi)
#
# NameError: name 'hi' is not defined

# %%
a = 10
a=+10
print(a)
# Out:
# 10

# %%
a = 10
a+=10
print(a)
# Out:
# 20

# %%
a = 20
a-=10 
print(a)
# Out:
# 10

# %%
a = 10
a *=10
print(a)
# Out:
# 100

# %%
a = 10
a/=10
print(a)
# Out:
# 1.0

# %%
a = 10
a %=10
print(a)
# Out:
# 0

# %%
a=10
a//=10
print(a)
# Out:
# 1

# %%
a=10
a**=10
print(a)
# Out:
# 10000000000

# %%
a=2
a**=2
print(a)
# Out:
# 4

# %%
a=6
a**=8
print(a)
# Out:
# 1679616

# %% [markdown]
# ### relational

# %%
a=10
b=40
print(a>b)
print(b>a)
print(a<=b)
print(a==b)
# Out:
# False
# True
# True
# False

# %%
# assign a list which contais 10,20,30,40 with variable a and print them
a=[10,20,30,40]
print(a)
# Out:
# [10, 20, 30, 40]

# %%
a=[10,20,30,40]
print(a[1])
# Out:
# 20

# %%
a=[10,20,30,40,50]
print(a[1])
print(a[2])
# Out:
# 20
# 30

# %%
a=[10,20,30,40,50]
print(a[1],a[2])
# Out:
# 20 30

# %% [markdown]
# ### List Slicing

# %%
lst=[10,20,30,40]
print(a[1:4])
# Out:
# [20, 30, 40]

# %%
lst=[10,20,30,40]
print(a[1:3])
# Out:
# [20, 30]

# %%
lst=[10,20,30,40]
lst.append(50)
print(lst)
# Out:
# [10, 20, 30, 40, 50]

# %%
lst=[10,20,30,40,50]
lst.remove(20)
print(lst)
# Out:
# [10, 30, 40, 50]

# %% [markdown]
# ### Tuple

# %%
lst=(1,2,3,4,5)
print(lst)
# Out:
# (1, 2, 3, 4, 5)

# %%
lst=(1,2,3,4,5)
print(lst(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 lst=(1,2,3,4,5)
# ----> 2 print(lst(1))
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# ### Type Conversion

# %%
a=40
b=80.9
c=a+9j
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a=int(input("enter a number : "))
# Out:
# enter a number :  3.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a=int(input("enter a number : "))
#
# ValueError: invalid literal for int() with base 10: '3.0'

# %%
a=float(input("enter a number"))
# Out:
# enter a number 3.0

# %%
value=complex(int(input()),int(input())
print
# Out:
#   Cell In[22], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
# write a python program to accept student values and display them
student_marks=int(input())
print(student_marks)
# Out:
#  67
# 67

# %%
print("----students marks----")
sub1=int(input())
sub2=int(input())
sub3=int(input())
sub4=int(input())
sub5=int(input())
total=sub1+sub2+sub3+sub4+sub5
avg=total/5
print(f"students marks:{sub1}")
print(f"students marks:{sub2}")
print(f"students marks:{sub3}")
print(f"students marks:{sub4}")
print(f"students marks:{sub5}")
print(f"Total:{total}")
print(f"Average:{avg}")
# Out:
# ----students marks----
#  90
#  99
#  9897
#  99
#  90
# students marks:90
# students marks:99
# students marks:9897
# students marks:99
# students marks:90
# Total:10275
# Average:2055.0

# %%
# write a python program to accept birth year and calculate age
birth_year = int(input("Enter your birth year: "))
age = 2026 - birth_year
print(f"age:{age}")
# Out:
# Enter your birth year:  2004
# age:22

# %%
# write a python program to calculate the area of rectangle
length = int(input("Enter lenght: "))
breadth = int(input("Enter breadth: "))
area = length * breadth
print("Area of rectangle =",area)
# Out:
# Enter lenght:  4
# Enter breadth:  7
# Area of rectangle = 28

# %%
# write a python program to calculate the are of circle
radius = float(input("Enter the radius of the circle: "))
area = 3.14 * radius * radius
print("Area of the circle =", area)
# Out:
# Enter the radius of the circle:  8
# Area of the circle = 200.96

# %% [markdown]
# # functions

# %%
# types of arguments
1.positional arguments
