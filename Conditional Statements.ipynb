# %%
# Chech whether the number is divisible with 3 or not.
num = int(input())
if num%3==0:
    print(f'{num} is divisible by 3')
else:
    print(f'{num} is not divisible with 3')
# Out:
#  6
# 6 is divisible by 3

# %%
# Check whether the number is divisible with 3 and 5 or not
num = int(input())
if num%3==0 and num%5==0:
    print(f'{num} is divisible by bothe 3 and 5')
else:
    print(f'{num} is not divisible by both 3 and 5')
# Out:
#  15
# 15 is divisible by bothe 3 and 5

# %%
# Check whether the number is even or not
num = int(input())
if num%4==0 or num%7==0:
    print(f'{num} is divisible with even or not')
else:
    print(f'{num} is not divisible with even or not')
# Out:
#  18
# 18 is not divisible with even or not

# %%
# Check whether the number is divisible with either 3 or 5
num = int(input())
if num%3==0 or num%5==0:
    print(f'{num} is divisible with either 3 or 5')
else:
    print(f'{num} is not divisible with either or 5')
# Out:
#  74
# 74 is not divisible with either or 5

# %%
# even or odd
num = int(input())
if num % 2==1:
    print(f'{num} is odd')
else:
    print(f'{num} is even')
# Out:
#  -2
# -2 is even

# %%
# even or odd
num = int(input())
if num & 1 == 0:
    print(f'{num} is even')
else:
    print(f'{num} is odd')
# Out:
#  3
# 3 is odd

# %%
# generate total bill if the total bill more than 500 then give 10% discount otherwise 0% discount
total_bill = int(input())
if total_bill > 500:
    discount = total_bill * 0.1
    print(f"Total bill After 10% discount: {total_bill - discount}")
else:
    print(f"Total bill After 0% discount: {total_bill}")
# Out:
#  500
# Total bill After 0% discount: 500

# %%
# generate total bill if the total bill more than 500 then give 10% discount otherwise 0% discount
total_bill = int(input())
if total_bill > 500:
    discount = total_bill * 0.1
    print(f"Total bill After 10% discount: {total_bill - discount}")
else:
    print(f"Total bill After 0% discount: {total_bill}")
# Out:
#  501
# Total bill After 10% discount: 450.9

# %%
# Check whether the product stock is available or not(read product name and stock)
product = input()
stock = int(input())
if stock > 0:
    print(f"currently {product} : {stock} items available")    
else:
    print(f'currently {product} out of stock')
# Out:
#  pen
#  20
# currently pen : 20 items available

# %%
# In a shop contains some items along with prices like {'pen':5
products = {'pen':5, 'book':20, 'pencil':3}
item = input()
quantity = int(input())
if item in products:
    total_amount = products.get(item) * quantity
    print(f'Total amount of {quantity} {item} is: {total_amount}')
else:
    print(f"{item} not available")
# Out:
#  pen
#  5
# Total amount of 5 pen is: 25

# %% [markdown]
# ### if elif-else

# %%
# Check weather the number is +ve , _ve or Zero
num = int(input())
if num > 0:
    print(f'{num} is +ve')
elif num < 0:
    print(f'{num} is -ve')
else:
    print(f'{num} is Zero')
# Out:
#  5
# 5 is +ve

# %%
# Check weather the number is +ve , _ve or Zero
num = int(input())
if num > 0:
    print(f'{num} is +ve')
elif num < 0:
    print(f'{num} is -ve')
else:
    print(f'{num} is Zero')
# Out:
#  0
# 0 is Zero

# %%
# Check weather the number is +ve , _ve or Zero
num = int(input())
if num > 0:
    print(f'{num} is +ve')
elif num < 0:
    print(f'{num} is -ve')
else:
    print(f'{num} is Zero')
# Out:
#  -10
# -10 is -ve

# %%
# divisible by 3 - Fizz
# divisible by 5 - Buzz
#both -FizzBuzz
num = int(input())
if num%3==0:
    print(f'{num} is Fizz')
elif num%5==0:
    print(f'{num} is buzz')
elif num%3==0 and num%5==0:
    print(f'{num} is Fizzbuzz')
else:
    print('invalid')
# Out:
#  15
# 15 is Fizz

# %%
# divisible by 3 - Fizz
# divisible by 5 - Buzz
#both -FizzBuzz
num = int(input())
if num%3==0 and num%5==0:
    print(f'{num} is Fizzbuzz')
elif num%5==0:
    print(f'{num} is buzz')
elif num%3==0:
    print(f'{num} is Fizzbuzz')
else:
    print('invalid')
# Out:
#  15
# 15 is Fizzbuzz

# %%
# check wheather the +ve is even,-ve is even,+ve is odd,and -ve is odd
num = int(input())
if num>0 and num%2==0:
    print(f"{num} positive Even")
if num<0 and num%2==0:
    print(f"{num} negative Even")
if num>0 and num%2!=0:
    print(f"{num} positive odd")
if num<0 and num%2!=0:
    print(f"{num} negative odd")
# Out:
#  9
# 9 positive odd

# %%
num = int(input())
if num<0 and num%2==0:
    print("negative even")
if num<0 and num%2==1:
    print("negative odd")
# Out:
#  -9
# negative odd

# %%
# check wheather the +ve is even,-ve is even,+ve is odd,and -ve is odd
n=int(input())
if n>0 and n%2==0:
    print(f"{n} is +ve even number")
else:
    print("-ve even")
# Out:
#  -7
# -ve even

# %%
n1, n2, n3 = map(int, input().split())
if n1 > n2 and n1 > n3:
    print(n1)
elif n2> n3:
    print(n2)
else:
    print(n3)
# Out:
#  33 99 21
# 99

# %% [markdown]
# ### Nested if

# %%
num = int(input("enter a number : "))
if num > 0:
    if num%2==0:
        print(f"{n} +ve even")
    else:
        print(f"{n} +ve odd")
else:
    if num > 0:
        if num%2==0:
            print(f"{n} -ve even")
    else:
        print(f"{n} -ve odd")
# Out:
# enter a number :  -4
# 9 -ve odd

# %%
n1, n2, n3 = map(int, input().split())
if n1 > n2:
    if n1 > n3:
        print(n1)
    else:
        print(n3)
else:
    if n2 > n3:
        print(n2)
    else:
        print(n3)
