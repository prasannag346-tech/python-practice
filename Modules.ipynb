# %%
import math
import random
import os
import sys

# %%
import math
print(math.ceil(4.25))   # It represents the Upperbound integer value
print(math.floor(4.25))  # It represents the Lowerbound integer value
print(math.factorial(5)) # It returns the factorial of a numner
print(math.gcd(10,6,4))  # It returns the Greatest Common Divisor
print(math.lcm(10,6,4))  # It returns the Least Common Multiplier
print(math.pow(10,3))    # pow(a, b) : It returns the Float type of a raise to b
print(math.sqrt(12))     # It returns the Squareroot value of a number
print(math.log10(4))     # To find the Log10 values
# Out:
# 5
# 4
# 120
# 2
# 60
# 1000.0
# 3.4641016151377544
# 0.6020599913279624

# %%
import random
print(random.random())  # This function Generates the random number between 0 to 1.
print(random.randint(1,6)) # This function Generates the random number between a range 
print(random.randint(1000,9999))  # 4 digit OTP generation
print(random.choice(['A',1,2,3,4,5,6,7,8,9,'J','Q','K']))  # This function returns the random value from the sequence
print(random.choices(['A',1,2,3,4,5,6,7,8,9,'J','Q','K'], k=13)) # This function returns the random value from sequence

arr = ['A',1,2,3,4,5,6,7,8,9,'J','Q','K']

print(random.shuffle(arr))
print(arr)
# Out:
# 0.7144049950705079
# 4
# 7443
# 1
# [3, 'Q', 2, 1, 9, 1, 3, 2, 'K', 8, 'J', 'K', 1]
# None
# [1, 5, 3, 7, 'A', 2, 6, 'J', 'K', 'Q', 4, 8, 9]

# %%
### who will reach the top(100) in less steps 
import random
2
count = 0
rolls = 0
print("Welcome to the who will reach Top In Less Steps Game")
while True:
    input("To throw a dice, please click enter button")
    face_val = random.randint(1, 6)
    if count + face_val <= 100:
        count += face_val
        
    rolls+=1
    if count == 100:
        print(f"your Dice value:{face_val}")
        print(f"You have reached the Top in {rolls} chances")
        break
    print(f"your dice value:{face_val}")
    print(f"your at {count} position in {rolls} chances")
    print("*" * 50)
# Out:
# Welcome to the who will reach Top In Less Steps Game
# To throw a dice, please click enter button 6
# your dice value:1
# your at 1 position in 1 chances
# **************************************************
# To throw a dice, please click enter button
# your dice value:5
# your at 6 position in 2 chances
# **************************************************

# %%
import os
print(os.getcwd()) # It returns the Current Working Cirectory
if not os.path.exists('a'): # os.path.exists(path): It returns the path exists
    os.mkdir('a')# this functions create new empty directory
if not os.path.exists('modules'):
    os.mkdir('modules')

os.chdir('modules')
print(os.getcwd())
# Out:
# C:\Users\Gnanaprasanna\OneDrive\Desktop\operators
# C:\Users\Gnanaprasanna\OneDrive\Desktop\operators\modules

# %%
print(os.getcwd())
print(os.listdir("."))
os.chdir("..") # This changes thw working directory as previous directory
print(os.getcwd())
# Out:
# C:\Users\Gnanaprasanna\OneDrive\Desktop\operators
# [' loops 1.ipynb', '.git', '.ipynb_checkpoints', 'a', 'built-in functions.ipynb', 'codeforces functions.ipynb', 'Conditional Statements.ipynb', 'condutional statements practice seccions.ipynb', 'dictionary.ipynb', 'Functions.ipynb', 'Generators.ipynb', 'Input Formating.ipynb', 'List Comprehension.ipynb', 'lists and tuple.ipynb', 'modules', 'Modules.ipynb', 'operators.py', 'Output Formating.ipynb', 'practice sliciing.ipynb', 'practice.ipynb', 'practice.linkedin.ipynb', 'Recursion and Lambda Functions.ipynb', 'Scope of Variable.ipynb', 'sets.ipynb', 'string slicing and string methods.ipynb', 'tuple.ipynb', 'Type conversions.ipynb', 'Types of arguments.ipynb', 'Untitled1.ipynb']
# C:\Users\Gnanaprasanna\OneDrive\Desktop
